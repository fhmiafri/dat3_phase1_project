# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Fahmi Afri
# * Student pace: part time
# * Scheduled project review date/time: 11/9/2022
# * Instructor name: Hardik Idnani
# * Blog post URL: https://github.com/fhmiafri/dsc-phase-1-project

# %%
# Your code here - remember to use markdown cells for comments as well!
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#import and merge Datasets

# %%
df=pd.read_csv('zippedData/bom.movie_gross.csv.gz')
df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
df2=pd.read_csv('zippedData/imdb.title.basics.csv.gz')
df2
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
df3=pd.read_csv('zippedData/imdb.title.ratings.csv.gz')
df3
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
df4 = pd.merge(df2,df3, on=['tconst'],how='left')

# %%
df4
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
df.rename(columns={"title":"primary_title"}, inplace=True)

# %%
df
# Out:
#                                     primary_title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
df5 = pd.merge(df4,df, on=['primary_title'],how='left')
df5
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146141  tt9916538                          Kuambil Lagi Hatiku
# 146142  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146143  tt9916706                              Dankyavar Danka
# 146144  tt9916730                                       6 Gunn
# 146145  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
#finding top 5 movie gross

# %%
moviegross = df5.sort_values(by = "domestic_gross", ascending=False).head(5)

# %%
moviegross
# Out:
#           tconst             primary_title  \
# 19050  tt1825683             Black Panther
# 72821  tt4154756    Avengers: Infinity War
# 60     tt0369610            Jurassic World
# 42224  tt2527336  Star Wars: The Last Jedi
# 62742  tt3606756             Incredibles 2
#
#                                 original_title  start_year  runtime_minutes  \
# 19050                            Black Panther        2018            134.0
# 72821                   Avengers: Infinity War        2018            149.0
# 60                              Jurassic World        2015            124.0
# 42224  Star Wars: Episode VIII - The Last Jedi        2017            152.0
# 62742                            Incredibles 2        2018            118.0
#
#                            genres  averagerating  numvotes studio  \
# 19050     Action,Adventure,Sci-Fi            7.3  516148.0     BV
# 72821     Action,Adventure,Sci-Fi            8.5  670926.0     BV
# ...

# %%
df5[['genres', 'domestic_gross']]
# Out:
#                       genres  domestic_gross
# 0         Action,Crime,Drama             nan
# 1            Biography,Drama             nan
# 2                      Drama             nan
# 3               Comedy,Drama             nan
# 4       Comedy,Drama,Fantasy             nan
# ...                      ...             ...
# 146141                 Drama             nan
# 146142           Documentary             nan
# 146143                Comedy             nan
# 146144                   NaN             nan
# 146145           Documentary             nan
#
# [146146 rows x 2 columns]

# %%
df5_test=df5[['genres', 'domestic_gross']]

# %%
df5_test.describe()
# Out:
#        domestic_gross
# count    3.342000e+03
# mean     2.986560e+07
# std      6.532329e+07
# min      1.000000e+02
# 25%      1.362500e+05
# 50%      1.950000e+06
# 75%      3.140000e+07
# max      7.001000e+08

# %%
df5_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146146 entries, 0 to 146145
# Data columns (total 2 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   genres          140738 non-null  object
#  1   domestic_gross  3342 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 3.3+ MB

# %%
df5.isnull()
# Out:
#         tconst  primary_title  original_title  start_year  runtime_minutes  \
# 0        False          False           False       False            False
# 1        False          False           False       False            False
# 2        False          False           False       False            False
# 3        False          False           False       False             True
# 4        False          False           False       False            False
# ...        ...            ...             ...         ...              ...
# 146141   False          False           False       False            False
# 146142   False          False           False       False             True
# 146143   False          False           False       False             True
# 146144   False          False           False       False            False
# 146145   False          False           False       False             True
#
#         genres  averagerating  numvotes  studio  domestic_gross  \
# ...

# %%
df5.dropna()
# Out:
#            tconst                    primary_title  \
# 48      tt0337692                      On the Road
# 54      tt0359950  The Secret Life of Walter Mitty
# 58      tt0365907      A Walk Among the Tombstones
# 60      tt0369610                   Jurassic World
# 61      tt0372538                              Spy
# ...           ...                              ...
# 140828  tt9151704        Burn the Stage: The Movie
# 141376  tt9225192                      Unstoppable
# 142619  tt9392532                        Neighbors
# 142940  tt9447594                      The Gambler
# 146080  tt9906218                      Unstoppable
#
#                          original_title  start_year  runtime_minutes  \
# 48                          On the Road        2012        124.00000
# 54      The Secret Life of Walter Mitty        2013        114.00000
# 58          A Walk Among the Tombstones        2014        114.00000
# 60                       Jurassic World        2015        124.00000
# ...

# %%
df5_test['genres']
# Out:
# 0           Action,Crime,Drama
# 1              Biography,Drama
# 2                        Drama
# 3                 Comedy,Drama
# 4         Comedy,Drama,Fantasy
#                   ...
# 146141                   Drama
# 146142             Documentary
# 146143                  Comedy
# 146144                     NaN
# 146145             Documentary
# Name: genres, Length: 146146, dtype: object

# %%
df5_test['genres'].dtypes
# Out:
# dtype('O')

# %%
pd.options.display.float_format = '{:.5f}'.format

# %%
df5_test.describe()
# Out:
#        domestic_gross
# count      3342.00000
# mean   29865596.88181
# std    65323287.80283
# min         100.00000
# 25%      136250.00000
# 50%     1950000.00000
# 75%    31400000.00000
# max   700100000.00000

# %%
m_gross = moviegross["domestic_gross"]

# %%
movie_grossplot = m_gross.plot(kind="bar")
movie_grossplot.set_xticklabels(moviegross["primary_title"])
movie_grossplot.set_title("Movie title to Movie gross")
plt.savefig("images4.png")
plt.show();

# %%
movie_grossplot = m_gross.plot(kind="bar")
movie_grossplot.set_xticklabels(moviegross["genres"])
movie_grossplot.set_title("Movie genres to Movie gross")
plt.savefig("images5.png")
plt.show();

# %%
df5.describe()
# Out:
#           start_year  runtime_minutes  averagerating      numvotes  \
# count  146146.000000    114407.000000   73858.000000  7.385800e+04
# mean     2014.621796        86.187620       6.332726  3.523584e+03
# std         2.733580       166.359165       1.474959  3.029362e+04
# min      2010.000000         1.000000       1.000000  5.000000e+00
# 25%      2012.000000        70.000000       5.500000  1.400000e+01
# 50%      2015.000000        87.000000       6.500000  4.900000e+01
# 75%      2017.000000        99.000000       7.400000  2.820000e+02
# max      2115.000000     51420.000000      10.000000  1.841066e+06
#
#        domestic_gross         year
# count    3.342000e+03  3366.000000
# mean     2.986560e+07  2014.058824
# std      6.532329e+07     2.445261
# min      1.000000e+02  2010.000000
# 25%      1.362500e+05  2012.000000
# 50%      1.950000e+06  2014.000000
# 75%      3.140000e+07  2016.000000
# max      7.001000e+08  2018.000000

# %%
#finding most rated genre

# %%
col_one_list = df2['genres'].tolist()
sent_str = ""
for x in col_one_list:
    sent_str += str(x) + ","
sent_str = sent_str.split(',')
sent_str
# Out:
# ['Action',
#  'Crime',
#  'Drama',
#  'Biography',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Fantasy',
#  'Comedy',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Biography',
#  'Drama',
#  'History',
#  'Documentary',
#  'Drama',
#  'Documentary',
#  'Animation',
#  'Drama',
#  'History',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Mystery',
#  'Action',
#  'Animation',
#  'Comedy',
#  'Biography',
#  'Comedy',
#  'Drama',
#  'Documentary',
#  'Documentary',
#  'Action',
#  'Drama',
#  'Documentary',
#  'History',
#  'Sci-Fi',
#  'Comedy',
#  'Thriller',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Animation',
#  'Sci-Fi',
#  'Action',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Horror',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Drama',
#  'Family',
#  'Adventure',
#  'Comedy',
#  'Romance',
#  'Comedy',
#  'Drama',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Adventure',
#  'Drama',
#  'Romance',
#  'Biography',
#  'Horror',
#  'Comedy',
#  'Drama',
#  'Adventure',
# ...

# %%
from collections import Counter

# %%
counts_average = Counter(sent_str).most_common()
print(counts_average)
type(counts_average)
# Out:
# [('Documentary', 43586), ('Drama', 41621), ('Comedy', 20843), ('Thriller', 9720), ('Horror', 8606), ('Biography', 8241), ('Action', 8110), ('Romance', 7782), ('Crime', 5851), ('History', 5793), ('Adventure', 5740), ('Family', 5608), ('Mystery', 4143), ('Music', 3800), ('Fantasy', 2940), ('Sci-Fi', 2727), ('Animation', 2292), ('Sport', 1949), ('News', 1524), ('War', 1229), ('Musical', 1140), ('Western', 388), ('Reality-TV', 60), ('Talk-Show', 19), ('Short', 10), ('Adult', 7), ('Game-Show', 2), ('', 1)]
# list

# %%
names = []
for x in counts_average:
    names.append(x[0])
values = []
for x in counts_average:
    values.append(x[1])
print(names)
print(values)
# Out:
# ['Documentary', 'Drama', 'Comedy', 'Thriller', 'Horror', 'Biography', 'Action', 'Romance', 'Crime', 'History', 'Adventure', 'Family', 'Mystery', 'Music', 'Fantasy', 'Sci-Fi', 'Animation', 'Sport', 'News', 'War', 'Musical', 'Western', 'Reality-TV', 'Talk-Show', 'Short', 'Adult', 'Game-Show', '']
# [43586, 41621, 20843, 9720, 8606, 8241, 8110, 7782, 5851, 5793, 5740, 5608, 4143, 3800, 2940, 2727, 2292, 1949, 1524, 1229, 1140, 388, 60, 19, 10, 7, 2, 1]

# %%
fig, ax = plt.subplots()
barlist=plt.bar(range(len(counts_average)), values, tick_label=names)
plt.xticks(rotation=90)
ax.set_ylabel('Number of movies for each genre')
ax.set_xlabel('Genres')
ax.set_title('2015-2019 TOP20 highest rated IMDB movies \n Most common genres \n', fontweight="bold")
barlist[0].set_color('blue')
barlist[1].set_color('green')
barlist[2].set_color('red')
barlist[3].set_color('purple')
plt.savefig("images2.png")

plt.show();

# %%
#finding average and suitbale runningtime for movie

# %%
df5.sort_values(by = "runtime_minutes" , ascending=False)
# Out:
#            tconst                                primary_title  \
# 132391  tt8273150                                    Logistics
# 44841   tt2659636                         Modern Times Forever
# 123469  tt7492094                                         Nari
# 87265   tt5068890                                      Hunger!
# 88718   tt5136218                                   London EC1
# ...           ...                                          ...
# 146133  tt9915790                              Bobbyr Bondhura
# 146140  tt9916428                          The Secret of China
# 146142  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146143  tt9916706                              Dankyavar Danka
# 146145  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 132391                                    Logistics        2012
# 44841                          Modern Times Forever        2011
# ...

# %%
df5_runtime = df5['runtime_minutes']

# %%
x=df5_runtime.array

# %%
plt.hist(x,bins=10 , range = (0,180))
plt.xlabel('runtime')
plt.ylabel('number of movies')
plt.title('y')
plt.savefig("images6.png")
plt.show()

# %%
#finding the highest number of votes for movies

# %%
df4_top_numvotes=df5.sort_values(by = "numvotes", ascending=False).head(5)

# %%
df4_top_numvotes
# Out:
#           tconst          primary_title         original_title  start_year  \
# 7066   tt1375666              Inception              Inception        2010
# 6900   tt1345836  The Dark Knight Rises  The Dark Knight Rises        2012
# 311    tt0816692           Interstellar           Interstellar        2014
# 20342  tt1853728       Django Unchained       Django Unchained        2012
# 356    tt0848228           The Avengers           The Avengers        2012
#
#        runtime_minutes                   genres  averagerating   numvotes  \
# 7066             148.0  Action,Adventure,Sci-Fi            8.8  1841066.0
# 6900             164.0          Action,Thriller            8.4  1387769.0
# 311              169.0   Adventure,Drama,Sci-Fi            8.6  1299334.0
# 20342            165.0            Drama,Western            8.4  1211405.0
# 356              143.0  Action,Adventure,Sci-Fi            8.1  1183655.0
#
#       studio  domestic_gross foreign_gross    year
# ...

# %%
df5[['genres' , 'numvotes']].max()
# Out:
# numvotes    1841066.0
# dtype: float64

# %%
#finding the most averagerating for movies

# %%
df4_top_averagerating=df5.sort_values(by = "averagerating" , ascending=False).head(5)

# %%
df4_top_averagerating
# Out:
#            tconst                    primary_title  \
# 87676   tt5089804  Fly High: Story of the Disc Dog
# 92456   tt5344358                    All Around Us
# 120586  tt7259300                   Calamity Kevin
# 144765  tt9715646                         Renegade
# 85713   tt4960818                  Revolution Food
#
#                          original_title  start_year  runtime_minutes  \
# 87676   Fly High: Story of the Disc Dog        2019             65.0
# 92456                     All Around Us        2019              NaN
# 120586                   Calamity Kevin        2019             77.0
# 144765                         Renegade        2019              NaN
# 85713                   Revolution Food        2015             70.0
#
#                   genres  averagerating  numvotes studio  domestic_gross  \
# 87676        Documentary           10.0       7.0    NaN             NaN
# 92456        Documentary           10.0       6.0    NaN             NaN
# ...
